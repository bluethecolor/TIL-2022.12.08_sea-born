# %% [markdown]
# # 2. 그래프와 시각화

# %% [markdown]
# ## 기본 설정

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.set_printoptions(precision=4, suppress=True)
np.random.seed(12345)

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(8, 6))  # 그림 크기 설정

# %% [markdown]
# ## matplotlib.pyplot의 시각화 도구 API

# %% [markdown]
# ### `matplotlib.pyplot.plot()`
# - 2차원 그래프를 그리는 함수이다.
# - y축 좌표들의 리스트 또는 어레이만 인자로 넣어줄 때이다. x축 좌표는 해당 값들의 인덱스로 사용됨
# - [참고](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
data_1 = np.arange(100) + 100
plt.plot(data_1)
plt.show()

# %% [markdown]
# ### `Figure` 객체와 서브플롯(subplot)

# %% [markdown]
# - 모든 그래프는 `Figure` 객체 내에 존재
# - `matplotlib.pyplot.figure()` 함수에 의해 생성

# %% [markdown]
# __참고:__
# - 주피터 노트북을 사용시  `matplotlib.pyplot.figure()`, `matplotlib.pyplot.add_subplot()` 등 그래프를 그래프화 관련된 함수들은 모두 같은 셀에서 실행되어야 한다.

# %%
plt.figure()
plt.show()

# %% [markdown]
# - 서브플롯(subplot)
#     - `Figure` 객체 내에 그래프를 그리기 위해 서브플롯(subplot)을 지정
#     - `add_subplot()` 함수를 이용하여 지정된 `Figure` 객체안에 그래프를 그릴 공간을 만들어 보자

# %%
fig = plt.figure()
fig.add_subplot(2,2,1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# - subplot 추가

# %%
fig = plt.figure()
ax_1 = fig.add_subplot(2,2,1)
ax_2 = fig.add_subplot(2,2,2)
# ax_3 = fig.add_subplot(2,2,3)
# ax_4 = fig.add_subplot(2,2,4)

# %% [markdown]
# #### 그래프 삽입
# - `matplotlib.pyplot.plot()`
# - `<object>.plot()`

# %% [markdown]
# ##### 방법 1: `matplotlib.pyplot.plot()`

# %% [markdown]
# - 마지막에 선언된 서브플롯에 그래프를 그린다.
# - 예) 누적합을 나타내는 그래프를 그려보자

# %%
from numpy.random import randn
data = randn(100).cumsum()

# %%
fig = plt.figure()
ax_1 = fig.add_subplot(2,2,1)
plt.plot(data)
ax_2 = fig.add_subplot(2,2,2)
# plt.plot(data, 'k-')
ax_3 = fig.add_subplot(2,2,3)
plt.plot(data, 'k--')
data
# Out:
# array([-0.5311, -0.7456,  1.2369,  0.7015,  1.8429,  1.4262,  0.0906,
#         0.3596, -1.0756, -1.539 , -1.7375, -1.822 , -2.1179, -3.2403,
#        -4.0852, -5.0102, -2.4599, -4.8126, -4.3388, -4.7879, -4.356 ,
#        -5.5976, -5.1853, -4.5677, -5.4115, -2.2216, -2.1506, -1.6336,
#        -2.4388, -1.4625, -0.603 , -0.3995, -0.4639,  0.0241,  1.3772,
#         1.6684,  1.6169,  2.97  ,  4.0361,  5.2964,  5.1523,  4.0782,
#         3.8331,  5.3074,  4.5657,  4.1033,  3.6836,  4.2758,  3.1092,
#         3.034 ,  3.1463,  3.3132,  3.3258,  4.1411,  3.4091,  4.2779,
#         4.4276,  4.9128,  5.0739,  4.0051,  5.1954,  4.1422,  4.9182,
#         6.2295,  7.3892,  7.8666,  7.8621,  8.4367,  9.531 ,  9.7102,
#        10.8261, 10.2384,  8.3307,  6.7255,  5.8919,  4.9275,  4.1894,
#         4.5769,  4.2795,  2.9574,  4.2157,  3.0854,  3.4704,  2.7768,
#         3.7434,  3.3688,  4.5988,  3.6979,  4.269 ,  1.6902,  2.6429,
#         2.5773,  3.3126,  2.0011,  1.2   ,  0.1144,  1.2834,  1.0258,
#        -0.2367, -1.0952])

# %% [markdown]
# ##### 방식 2: `객체명.plot()` 함수 활용

# %%
fig = plt.figure()
ax_1 = fig.add_subplot(2,2,1)
ax_2 = fig.add_subplot(2,2,2)
ax_3 = fig.add_subplot(2,2,3)

ax_1.plot(data)
ax_2.plot(data, 'k-')
ax_3.plot(data, 'k--')

# %%
# 2x2인 subplot을 만들고
# 임의의 데이터를 만들어서 ex) cunsum, np.arange(50) + 4 * np.random.rand(50) (기울기 1인 직선 + noise)
# 첫번째에는 scatter
# 두번쨰에는  histo
# 세번쨰에는  plot
# 을 그려보세요.

# %%
data_1 = 4 * np.random.rand(100)
data_2 = np.arange(50) + 4 * np.random.rand(50)
data_3 = randn(100).cumsum()

fig_1 = plt.figure()
ax__1 = fig_1.add_subplot(2,2,1)
ax__2= fig_1.add_subplot(2,2,2)
ax__3= fig_1.add_subplot(2,2,3)

ax__1.plot(data_1)
ax__2.plot(data_2, 'k-')
ax__3.plot(data_3, 'k--')

# %% [markdown]
# - 특정 서브플롯에 그래프를 삽입하려면 객체 이름과 함께 `plot()` 함수 등을 호출

# %% [markdown]
# #### 서브플롯 관리

# %% [markdown]
# - `matplotlib.pyplot.subplots()`
#     - 여러 개의 서브플롯을 포함하는 `Figure` 객체를 관리해준다.
#
# - 예) 2x3 크기의 서브플롯을 담은 (2,3) 모양의 넘파이 어레이로 생성.

# %%
fig = plt.subplots(2,3)

# %% [markdown]
# - `plt.subplots_adjust()`
#     - 각 서브플롯 사이의 여백을 조절
#     - 여백의 크기는 그래프의 크기와 숫자에 의존한다.

# %% [markdown]
# - 예) 여백이 0인 경우

# %%
fig, axes = plt.subplots(2,3)

for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.rand(300), bins = 100)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(2,3)
print(fig)
print(axes)
# Out:
# Figure(800x600)
# [[<AxesSubplot: > <AxesSubplot: > <AxesSubplot: >]
#  [<AxesSubplot: > <AxesSubplot: > <AxesSubplot: >]]

# %%
fig, axes = plt.subplots(2,3)
plt.subplots_adjust()
# () 공백으로 놔도 알아서 보기 좋게 나옴.

# %% [markdown]
# - 예) 여백이 1인 경우

# %%
fig, axes = plt.subplots(2,3)

plt.subplots_adjust(wspace=1,hspace=1)

# %% [markdown]
# ### 색상, 마커, 선 스타일

# %% [markdown]
# - 그래프의 속성을 변경하면 스타일이 변경된다.
# - 방법 1: 문자열 방식
#
# ```python
# ax.plot(x, y, 'g--')
# ```

# %% [markdown]
# - 방법 2: 키워드 인자 지정 방식
#
# ```python
# ax.plot(x, y, linestyle='--', color='g')
# ```

# %%
plt.plot(randn(100).cumsum(),'g--')

# %%
plt.plot(randn(100).cumsum(), marker = 'o', linestyle = 'dashed', c = "orange")

# %% [markdown]
# 색상은 RGB 값을 HEX 코드를 이용하여 직접 사용 가능
# - [RGB HEX 코드 link](https://www.w3schools.com/colors/colors_rgb.asp)

# %% [markdown]
# #### 여러 그래프 하나의 서브플롯에 그리기

# %% [markdown]
# - 여러 스타일의 그래프를 하나의 서브플롯에 그려 다양한 정보를 동시에 전달

# %%
data
# Out:
# array([-0.5311, -0.7456,  1.2369,  0.7015,  1.8429,  1.4262,  0.0906,
#         0.3596, -1.0756, -1.539 , -1.7375, -1.822 , -2.1179, -3.2403,
#        -4.0852, -5.0102, -2.4599, -4.8126, -4.3388, -4.7879, -4.356 ,
#        -5.5976, -5.1853, -4.5677, -5.4115, -2.2216, -2.1506, -1.6336,
#        -2.4388, -1.4625, -0.603 , -0.3995, -0.4639,  0.0241,  1.3772,
#         1.6684,  1.6169,  2.97  ,  4.0361,  5.2964,  5.1523,  4.0782,
#         3.8331,  5.3074,  4.5657,  4.1033,  3.6836,  4.2758,  3.1092,
#         3.034 ,  3.1463,  3.3132,  3.3258,  4.1411,  3.4091,  4.2779,
#         4.4276,  4.9128,  5.0739,  4.0051,  5.1954,  4.1422,  4.9182,
#         6.2295,  7.3892,  7.8666,  7.8621,  8.4367,  9.531 ,  9.7102,
#        10.8261, 10.2384,  8.3307,  6.7255,  5.8919,  4.9275,  4.1894,
#         4.5769,  4.2795,  2.9574,  4.2157,  3.0854,  3.4704,  2.7768,
#         3.7434,  3.3688,  4.5988,  3.6979,  4.269 ,  1.6902,  2.6429,
#         2.5773,  3.3126,  2.0011,  1.2   ,  0.1144,  1.2834,  1.0258,
#        -0.2367, -1.0952])

# %%
plt.plot(data, 'k--')

# %%
plt.plot(data, drawstyle = "steps-post")

# %%
plt.plot(data, 'k--', label = "default")
plt.plot(data, drawstyle = "steps-post", label = "steps")
# 겹쳐서 그려짐.

# label의 범례 위치를 지정하여, 가장 적절한 위치로 지정하여 자동으로 생성
plt.legend(loc = "best")
# plt.legend(loc = "best")

# %% [markdown]
# - 범례 표기
#     - `plt.legend()`
#     - `loc='best'`: 범례 위지 지정. 기본값은 auto

# %% [markdown]
# ### 눈금과 라벨

# %% [markdown]
# #### 이미지 타이틀, 축 이름, 눈금, 눈금 이름 지정

# %% [markdown]
# ##### 방법 1: 파이플롯 객체의 메서드 활용
# - `set_xticks()` 함수: 눈금 지정
# - `set_xticklabels()` 함수: 눈금 라벨 지정
# - `set_title()` 함수: 그래프 타이틀 지정
# - `set_xlabel()` 함수: x축 이름 지정

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(data)

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one','two','three','four','five'])

ax.set_title('plot')
ax.set_xlabel('status')
# Out:
# Text(0.5, 0, 'status')

# %% [markdown]
# ##### 방법 2: pyplot 모듈의 함수 활용
# - `plt.xticks()` 함수: 눈금 및 눈금 라벨 지정
# - `plt.title()` 함수: 그래프 타이틀 지정
# - `plt.xlabel()` 함수: x축 이름 지정

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(data)

plt.xticks([0, 250, 500, 750, 1000],['one','two','three','four','five'],
            rotation = 45)

plt.title('plot')
plt.xlabel('status')
# Out:
# Text(0.5, 0, 'status')

# %% [markdown]
# ### 서브플롯에 주석 및 도형 추가하기

# %% [markdown]
# #### 주석 추가

# %% [markdown]
# 설명을 위해 S&P 500 (스탠다드 앤 푸어스, Standard and Poor's 500)의 미국 500대 기업을 포함한
# 주식시장지수 데이터로 그래프를 생성하고 2007-2008년 사이에 있었던
# 재정위기와 관련된 중요한 날짜를 주석으로 추가한다.

# %%
spx_path = "https://raw.githubusercontent.com/myoh0623/dataset/main/spx.csv"

# %%
data = pd.read_csv(spx_path)
data
# Out:
#                Unnamed: 0      SPX
# 0     1990-02-01 00:00:00   328.79
# 1     1990-02-02 00:00:00   330.92
# 2     1990-02-05 00:00:00   331.85
# 3     1990-02-06 00:00:00   329.66
# 4     1990-02-07 00:00:00   333.75
# ...                   ...      ...
# 5467  2011-10-10 00:00:00  1194.89
# 5468  2011-10-11 00:00:00  1195.54
# 5469  2011-10-12 00:00:00  1207.25
# 5470  2011-10-13 00:00:00  1203.66
# 5471  2011-10-14 00:00:00  1224.58
#
# [5472 rows x 2 columns]

# %% [markdown]
# 시간 컬럼을 행의 인덱스로 사용하자
#
# - `index_col=0`: 0번 열(column)을 인덱스로 사용
# - `parse_dates=True`: 년월일까지만 구분해서 인덱스로 사용. 기본값은 `False`.

# %%
data = pd.read_csv(spx_path, index_col=0, parse_dates=True)
data
# Out:
#                 SPX
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# ...             ...
# 2011-10-10  1194.89
# 2011-10-11  1195.54
# 2011-10-12  1207.25
# 2011-10-13  1203.66
# 2011-10-14  1224.58
#
# [5472 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5472 entries, 1990-02-01 to 2011-10-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPX     5472 non-null   float64
# dtypes: float64(1)
# memory usage: 85.5 KB

# %% [markdown]
# - 위 데이터를 그래프로 나타내 보자

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

data.plot(ax = ax)
# Out:
# <AxesSubplot: >

# %% [markdown]
# 2007-2008년 세계적 금융위기 지점을 아래 내용으로 그래프에 주석으로 추가해보자.
#
# - 2007년 10월 11일: 주가 강세장 위치 'Peak of bull market'
# - 2008년 3월 12일: 베어스턴스 투자은행 붕괴 'Bear Stearns Fails'
# - 2008년 9월 15일: 레만 투자은행 파산 'Lehman Bankruptcy'

# %%
from datetime import datetime

# %%
annot_data = [(datetime(2007,10,11), 'peak of bull market'),
              (datetime(2008,3,12), 'bear stearns Fails'),
              (datetime(2007,9,15), 'Lehman Bankruptcy')
              ]

# %% [markdown]
# #### `annotate()`

# %% [markdown]
# - `xt` 속성: 화살표 머리 위치
# - `xytext` 속성: 텍스트 위치
# - `arrowprops` 속성: 화살표 속성
# - `horizontalalignment`: 텍스트 좌우 줄맞춤
# - `verticalalignment`: 텍스트 상하 줄맞춤

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data.plot(ax=ax, style='k-')

for date, label in annot_data:
    ax.annotate(label, 
                xy=(date, data.asof(date) + 75),
                xytext=(date, data.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')
    
ax.set_xlim([datetime(2007,1,1),  datetime(2011,1,1)])    
ax.set_ylim(600,2000)
plt.show()

# %% [markdown]
# #### 도형 추가

# %% [markdown]
# 지정된 함수를 이용하여 다양한 도형을 추가 가능
#
# - `plt.<도형명>((위치), 크기)`
# - `plt.Rectangle()`: 직사각형. 왼편 아래 좌표 및 가로 세로 길이
# - `plt.Circle()`: 원. 원의 중심 좌표 및 반지름.
# - `plt.Polygon()`: 다각형. 각 꼭지점의 좌표.

# %% [markdown]
# __주의사항:__
# - x, y축의 눈금이 다르면 도형이 정확하게 표현되지 않을 수 있다.
# - 예를 들어, 두 축의 척도가 다르면 원이 타원으로 보일수 있음
#     - `Figure` 객체를 생성할 때 두 축의 크기를 동일하게 지정하면 척도가 동일해 진다.

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
np.random.seed(12345)


fig = plt.figure(figsize=(10, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
circ = plt.Circle((10, 10), 5, color='b', alpha=0.3)
ax2.add_patch(circ)
    

plt.show()

# %% [markdown]
# ### 그래프 저장하기

# %% [markdown]
# `plt.savefig()`
#
# - `dpi=100`: 인치당 픽셀 수. 저장된 이미지의 해상도 지정.
# - `bbox_inches=tight`: 이미지별 둘레의 공백 지정. 여기서는 공백을 거의 사용하지 말라는 의미임.

# %% [markdown]
# ### matplotlib 기본 설정

# %% [markdown]
# `plt.rc()` 함수를 이용하여 matplot을 이용하여 생성되는 이미지 관련 설정을 전역적으로 지정할 수 있다.
# 사용되는 형식은 다음과 같다.
#
# - 첫째 인자: 속성 지정
# - 둘째 인자: 속성값 지정
#
# __참고:__ 'rc' 는 기본설정을 의미하는 단어로 많이 사용된다.
# 풀어 쓰면 "Run at startup and they Configure your stuff",
# 즉, "프로그램이 시작할 때 기본값들을 설정한다"의 의미이다.
# '.vimrc', '.bashrc', '.zshrc' 등 많은 애플리케이션의 초기설정 파일명에 사용되곤 한다.
#
# 아래 코드는 이미지의 사이즈를 지정한다.

# %%
plt.rc('figure', figsize=(10, 10))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
plt.show()

# %% [markdown]
# 아래 코드는 다양한 속성을 지정하는 방식을 보여준다.

# %% [markdown]
# * 이미지 사이즈 지정

# %% [markdown]
# * 선 속성 지정

# %% [markdown]
# * 텍스트 폰트 속성 지정

# %% [markdown]
# * 그래프 구성 요소의 색상 지정

# %% [markdown]
# 아래 코드는 앞서 설정된 다양한 속성을 반영한 결과를 보여준다.

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

spx.plot(ax=ax, style='-')

for date, label in crisis_data:
    ax.annotate(label, 
                xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

plt.show()
